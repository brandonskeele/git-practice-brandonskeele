# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('brady.csv')

# %%
## Try to reproduce the scatterplot below 
## (or close to it) in matplotlib, seaborn, and/or plotly express

# %%
df
# Out:
#     Year  Rating  Completions  TDs  Yards  Attempts          Outcome
# 0   2000    42.4            1    0      6         3  Missed Playoffs
# 1   2001    86.5          264   18   2843       413       Super Bowl
# 2   2002    85.7          373   28   3764       601  Missed Playoffs
# 3   2003    85.9          317   23   3620       527       Super Bowl
# 4   2004    92.6          288   28   3692       474       Super Bowl
# 5   2005    92.3          334   26   4110       530    Made Playoffs
# 6   2006    87.9          319   24   3529       516    Made Playoffs
# 7   2007   117.2          398   50   4806       578       Super Bowl
# 8   2008    83.9            7    0     76        11  Missed Playoffs
# 9   2009    96.2          371   28   4398       565    Made Playoffs
# 10  2010   111.0          324   36   3900       492    Made Playoffs
# 11  2011   105.6          401   39   5235       611       Super Bowl
# 12  2012    98.7          401   34   4827       637    Made Playoffs
# ...

# %%
fig, ax = plt.subplots(figsize=(5, 4))
sns.set_style("darkgrid")
plot = sns.scatterplot(data=df, x="Year", y="Completions", hue="Outcome", style="Outcome", s=50)
plot.set_title("Number of Completions by Year")
sns.move_legend(plot, loc='lower left', bbox_to_anchor=(1, 0))
plot.legend_.set_title(None)
plot
# Out:
# <Axes: title={'center': 'Number of Completions by Year'}, xlabel='Year', ylabel='Completions'>

# %%
## DO NOT RUN THIS CELL

# %% [markdown]
# ----

# %%
## Try to reproduce the boxplots below 
## (or close to it) in matplotlib, seaborn, and/or plotly express

# %%
sns.set_palette(palette="mako_r")
plot = sns.boxplot(data=df, x="Outcome", y="Completions", hue="Outcome")
plot.set(xlabel="")
# Out:
# [Text(0.5, 0, '')]

# %%
## DO NOT RUN THIS CELL

# %% [markdown]
# ---

# %%
## Try to reproduce the regression plots below 
## (or close to it) in matplotlib, seaborn, and/or plotly express

# %%
## DO NOT RUN THIS CELL

# %% [markdown]
# ---

# %%
## Try to reproduce the barchart below 
## (or close to it) in matplotlib, seaborn, and/or plotly express

# %%
## DO NOT RUN THIS CELL

# %% [markdown]
# ---

# %%
df['pct'] = df['Completions']/df['Attempts']

# %%
## Try to reproduce the lineplot below 
## (or close to it) in matplotlib, seaborn, and/or plotly express

# %%
## DO NOT RUN THIS CELL

# %% [markdown]
# ---

# %%
## Try to reproduce the scatterplot below 
## (or close to it) in either matplotlib, seaborn, and/or plotly express

# %%
## DO NOT RUN THIS CELL
